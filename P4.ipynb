# %% [markdown]
# <a href="https://colab.research.google.com/github/sergiocarp10/unlp-tramo-final/blob/main/P4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Instalamos Spark para Python
# !pip install pyspark

import os

# Instalamos Java SDK 8
# !apt-get install -y openjdk-8-jdk -qq > /dev/null      
# !echo $(/usr/libexec/java_home -v 1.8)

#set environment variable
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"     
# !echo 2 | update-alternatives --config java
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyspark
#   Downloading pyspark-3.3.0.tar.gz (281.3 MB)
#      |████████████████████████████████| 281.3 MB 46 kB/s
# Collecting py4j==0.10.9.5
#   Downloading py4j-0.10.9.5-py2.py3-none-any.whl (199 kB)
#      |████████████████████████████████| 199 kB 59.1 MB/s
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.3.0-py2.py3-none-any.whl size=281764026 sha256=12faac5fe2d2e85d6e0584ab2785ccaeff7284203418e01d0909c3a2dd13ae9f
#   Stored in directory: /root/.cache/pip/wheels/7a/8e/1b/f73a52650d2e5f337708d9f6a1750d451a7349a867f928b885
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9.5 pyspark-3.3.0
# /bin/bash: /usr/libexec/java_home: No such file or directory
#
# There are 2 choices for the alternative java (providing /usr/bin/java).
#
#   Selection    Path                                            Priority   Status
# ------------------------------------------------------------
# * 0            /usr/lib/jvm/java-11-openjdk-amd64/bin/java      1111      auto mode
#   1            /usr/lib/jvm/java-11-openjdk-amd64/bin/java      1111      manual mode
#   2            /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/java   1081      manual mode
#
# Press <enter> to keep the current choice[*], or type selection number: update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/java to provide /usr/bin/java (java) in manual mode

# %%
from pyspark import SparkContext
sc = SparkContext("local", "MyProgram")

# %%
root_path = 'drive/My Drive/Colab Notebooks/'

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

import datetime, math
import sys
sys.path.append('/content/' + root_path)

inputDir = root_path + "Banco/"
outputDir = root_path + "output_TP4/"

# ------------------- transformaciones ----------------------

# Cliente: <ID_Cliente, nombre, apellido, DNI, fecha de nacimiento, nacionalidad>
# CajaDeAhorro: <ID_Caja, ID_Cliente, saldo>
# Prestamos: <ID_Caja, cuotas, monto>
# Movimientos: <ID_Caja, monto, timestamp>

def lineToTuple(linea):
  return linea.split('\t')

# ------------------------------------------------------------

# fuentes
clientes = sc.textFile(inputDir + "clientes")
cajas = sc.textFile(inputDir + "cajas")
prestamos = sc.textFile(inputDir + "prestamos")
movimientos = sc.textFile(inputDir + "mov")

# de lineas a tuplas
clientes = clientes.map(lineToTuple)
cajas = cajas.map(lineToTuple)
prestamos = prestamos.map(lineToTuple)
movimientos = movimientos.map(lineToTuple)

# convertimos la fecha de nacimiento en año, mes y día (enteros)
clientes = clientes.map(lambda t: (t[1] + " " + t[2], t[4].split("-"), t[5]))
clientes = clientes.map(lambda t: (t[0], int(t[1][0]), int(t[1][1]), int(t[1][2]), t[2]))

# en cajas pasamos los saldos a real
cajas = cajas.map(lambda c: (c[0], c[1], float(c[2])) )

# en prestamos pasamos las cuotas a numero
prestamos = prestamos.map(lambda t: (t[0], int(t[1]), t[2]) )

# en movimientos pasamos los montos a real // timestamp lo dejamos asi nomas
movimientos = movimientos.map(lambda m: (m[0], float(m[1]), m[2]) )

# ayudita de formato
print(cajas.first())
print(prestamos.first())
print(movimientos.first())
print('\n')

## Inciso A: nombre y apellido de capricornianos, es decir, 22/12 al 19/1
# la cuarta columna (contando desde 0) es la fecha de nacimiento
incisoA = clientes.filter(lambda t: (t[2] == 1 and t[3] < 20) or (t[2] == 12 and t[3] > 21) )
incisoA = incisoA.map(lambda t: t[0] )
print(incisoA.collect())

## Inciso B: nombre y apellido de argentinos
# la nacionalidad es la quinta columna
argentinos = clientes.filter(lambda t: t[4] == 'ARG')
incisoB = argentinos.map(lambda t: t[0])
print(incisoB.collect())

## Inciso C: de (a), cuántos nacieron en verano
print("De capricornio, en verano nacieron " + str(incisoA.count()))

## Inciso D: de (b) el más joven y el más viejo
# para ordenar por más de un parámetro se utiliza una tupla
print(argentinos.sortBy(lambda t: (t[1], t[2], t[3]), ascending=False).first())
print(argentinos.sortBy(lambda t: (t[1], t[2], t[3]), ascending=True).first())

## Inciso E: el préstamo con mayor cantidad de cuotas (columna 1)
maximoCuotas = prestamos.reduce(lambda p1, p2: p1 if p1[1] > p2[1] else p2)

# ... las que tienen misma cantidad de cuotas, el mayor monto
masCuotas = prestamos.filter(lambda p: p[1] == maximoCuotas[1])
mayorMonto = masCuotas.reduce(lambda p1, p2: p1 if p1[2] > p2[2] else p2 )
print(mayorMonto)

## Inciso F: id de clientes con al menos una caja con saldo > 300
saldosMayor = cajas.filter(lambda c: c[2] > 300)
idSaldosMayor = cajas.map(lambda c: c[1] )
print(idSaldosMayor.collect())

## Inciso G: monto de mayor movimiento e ID de caja del ultimo mov
mayorMov = movimientos.reduce(lambda m1, m2: m1 if m1[1] > m2[1] else m2)
print("Monto del mayor movimiento: " + str(mayorMov[1]))

ultimoMov = movimientos.reduce(lambda m1, m2: m1 if m1[2] > m2[2] else m2)
print("ID de caja del ultimo mov: " + ultimoMov[0])
# Out:
# Mounted at /content/drive
# ('336442', '91893', -87702.5531547622)
# ('399580', 54, '1432.83477152364')
# ('505753', 49837.5266323972, '2004-05-12 12:19:07')
#
#
# ['Usrqz Vxfyrk', 'Yhfeci Zvixkb', 'Gmviqsc Hgmdf', 'Moitln Pjcwje', 'Nbvyg Fsvnzp', 'Trahy Fdiph', 'Okqsd Bqecx', 'Yoohis Rlfrnjvd', 'Oyqvost Gfdsx', 'Woanu Dekdye', 'Jnert Troflo', 'Awqhees Tzidotgg', 'Ehsgnd Tzdydv', 'Bacwt Vsxtl', 'Ehzdb Orbppc', 'Qieaijyy Whbofvw', 'Ijeqspr Mssrm', 'Elydgs Zefebcgv', 'Nletwyvm Miwhck', 'Bsjer Jijkf', 'Qtdpbni Kxjmbsy', 'Iwgfdrt Brixxfqj', 'Mchpwp Mzrbthn', 'Jzzzsko Eoccql', 'Gzyscak Gpereqb', 'Orhfqqck Afqidrqj', 'Dzxns Nizxk', 'Pobfhxio Uxpyyic', 'Dppnsx Lqqatpw', 'Xnqzhka Njunmrtf', 'Dxlzxz Epvjfk', 'Jqdqilz Owziy', 'Jiafdnvr Uvdkmrv', 'Jdrpdex Jlfupfr', 'Dyxprln Skbvsvs', 'Gvtxh Opgwkqk', 'Vvcfbzea Mfqxjx', 'Nbzzcp Ijpik', 'Tldil Smqpihbm', 'Xgjwwcw Ohhfwi', 'Upcmog Arsiajxy', 'Ifrxlouz Mwtjtior', 'Hszptnrb Rereyjr', 'Idmvnqz Srudh', 'Mfngw Isowo', 'Pnkiwrja Vybqv', 'Ozobsy Htzujxdd', 'Xdwshpi Upxzutam', 'Rpufpw Pqicto', 'Ebaarllv Wvvghdf', 'Haevozzt Utzxi', 'Srmlheah Vnugagv', 'Jkhbx Bvrldcdf', 'Syrflzr Dhhutu', 'Utgky Dlvopequ', 'Kzpzrb Gsjazq', 'Tgoyg Bzdvf', 'Xmyjq Eedmjf', 'Bpxvh Unvbjyd', 'Fynwxem Dbrogypi', 'Vfaro Sfrexe', 'Ookqms Hbukgizl', 'Fzkrok Ymjgdaqn', 'Izkhwm Chcwjc', 'Ahnwmqjn Tbubqh', 'Xdnvldws Oackzghd', 'Rrauwq Siatpha', 'Xagno Fjxpxxce', 'Ufyfaxn Zxirkifo', 'Nxgpl Jcbccoz', 'Rdnakeqk Mqqwgd', 'Mwdfydnq Kxdwepp', 'Idlaybt Iwsmnqky', 'Miwxam Ghclgdq', 'Tqlqoecp Iuezv', 'Zphhtp Smniw', 'Xfkzcya Ltpyd', 'Yvbuo Aofws', 'Bzmtpmp Trozqex', 'Fkuqg Davqlk', 'Yoyvy Joxbvkh', 'Wvjmwrwi Hkuwhb', 'Fgfdaei Tvbqy', 'Rtgqgwmv Lokardbu', 'Vvbwhuzb Bspmbucv', 'Qyyuxm Aovsjhzd', 'Skzjqdot Mzmguvwr', 'Qkzalavo Axyonydy', 'Iasvhga Yryjbpb', 'Ceqpmhn Ghonzfo', 'Kllgee Wquic', 'Wzuapl Slvfjkom', 'Lzhnlpsw Aqoyc', 'Jrrgui Ffikcnh', 'Muanzbvr Prsim', 'Cgftfibn Ramxkrof', 'Qgyujvo Zutlwnwz', 'Zajzg Hrxrkxq', 'Dytckv Ymhdzo', 'Irlbomx Wvphsy', 'Kzzftcrh Pbmzkogz', 'Qsomdyr Ojkpoll', 'Szvhp Rwdozgb', 'Oetesmsx Chjwbofs', 'Wuyanqkq Cvgyxbkr', 'Khxmqyws Hpszj', 'Kjtungxg Ktrwenm', 'Wiyqzcj Adwcyono', 'Vginpnl Xxacur', 'Pdzyklqb Tnfrzf', 'Xtsrtmpb Rjgufsj', 'Ilumaz Ghgnxc', 'Gavnrut Rdiok', 'Mbvwz Ugmkktr', 'Lvedefk Jufzmol', 'Pxkohb Wwksjqc', 'Eivkkw Gurvsdl', 'Ahylm Maafnoy', 'Covwwgi Doyvg', 'Giiyz Aqtab', 'Ticxc Qzcbbhlv', 'Lrkjg Sotkias', 'Pxvfxso Fgoqq', 'Vcoqclru Kocvty', 'Euehqle Dqssgd', 'Uwkrap Xovyozge', 'Tuykq Qfvnshni', 'Cxmqw Ofrnqw', 'Emwsz Hkazqtgu', 'Zaguz Xmurobc', 'Qvvgx Hkxuxll', 'Nhzzcjdt Fpjzjbk', 'Oleqkcx Pfyvgwdl', 'Ldxtwj Goplrq', 'Tugqxjb Vtztdt', 'Bwryftvk Rhzrn', 'Jynez Xzqcnhfs', 'Xatzd Wynmnj', 'Cgyik Tkvwjx', 'Xscls Grwwrzbd', 'Viaiicrs Cdxmoxj', 'Jfqzj Vnnown', 'Vmmnpm Xnynezxr', 'Wolggk Vhtpnqf', 'Hjqupmoz Kvpquh', 'Rrqzvai Dxmmsq', 'Iqmpm Aakuzylo', 'Xkolkyfp Xgjoamfn', 'Lompq Xeaab', 'Lyypmb Kravbww', 'Wkjki Buhkxh', 'Trgrawjr Tabsikui', 'Klssxrxy Ktibhww', 'Sletdilm Jdwhkkf', 'Vyqddrku Jbuvkaj', 'Ixxbl Ijvliugm', 'Qdhvgep Wtqxx', 'Hfpjsi Hjkpuzty', 'Aojqyehm Axmwn', 'Tzxphv Pootmrg', 'Rqtbgsbg Wmraktae', 'Iwwhfnlp Tacldgg', 'Obltana Djcwc', 'Gtzqrsrx Sxsdah', 'Picvj Glxibvwd', 'Vzkfwivd Rkecjhdd', 'Koqyivpg Qamvpfq', 'Rbuwjg Shbszu', 'Wztdqh Oxvogniy', 'Dbmxnua Kdzfhwef', 'Sqadnjw Xludecgm', 'Unxhogy Wallwdco', 'Pxsqgo Mrazszw', 'Angsqi Isfxgxv', 'Smhqud Sedkyj', 'Enzlucq Ydfgafb', 'Tcrzao Zhxvdk', 'Eanpsyge Pxhdhd', 'Fujffc Szjns', 'Hfewnquk Iiyjnw', 'Xltumwz Vdgkm', 'Cwiqc Gaiou', 'Tsjbpzju Vjuun', 'Jbsxo Wnpzvax', 'Pneoy Kikmgfz', 'Ddvnfwm Ttdhgoi', 'Idyefh Jukyvn', 'Yrpzr Bkcmqcn', 'Ghyyxsel Kcxfzy', 'Myjihjld Ljvxglkh', 'Hvitcp Aptnyoql', 'Roivzee Jyoyfkf', 'Qhrvfj Gvqcacac', 'Kgkbs Mzfnf', 'Bwnmawhd Hlhutwym', 'Vvhilqyg Vorzktxn', 'Oiewcy Xquggc', 'Ryoadzd Uxhyluy', 'Eyokrl Tgwkxdfj', 'Tjanv Lertrmr', 'Ayibhi Zurrn', 'Robvzkix Tgdddl', 'Cqptax Pjfmj', 'Jnxmncm Adqhu', 'Vbitewtg Lxymcebg', 'Gyxtedme Gyfel', 'Ykeyciyz Dmdeqb', 'Fbzbiao Uvbrwokm', 'Hkgljwru Wlsgez', 'Krjnnb Syffbdc', 'Yingph Tmaiszx', 'Lqfmu Aeifna', 'Vznuwt Fqfgs', 'Akxcw Ndzbg', 'Nppnfbl Zvewglp', 'Hqcezpdf Gckln', 'Onxgfca Qoprou', 'Kiogn Tseoj', 'Paqhohto Qriczdq', 'Vxexrh Ognwkm', 'Yhwc ...
# ['Cdfglg Vocflg', 'Llllup Dwcybxcu', 'Bgkmr Qsdvyfj', 'Ayedk Fqvsarvj', 'Vpsmir Fdylbwin', 'Lyovlyi Opkgvn', 'Slsiyfea Jrcsj', 'Ehaoswaa Ncpaukc', 'Doyzyqt Aiaerbjo', 'Drqwlzir Jymrd', 'Rlkaxadr Vbxqlbn', 'Rjvoltnc Gnxhevt', 'Jgdwojin Wyciqlhw', 'Wpyvgjtv Kaykv', 'Orfaw Ooicj', 'Ttypapjn Dictasrr', 'Vazxugj Mtuktofx', 'Imhsajyk Fgwkfcdv', 'Yqfcx Ycsbjqa', 'Igvqnghi Vbyul', 'Quijdxmk Tdxvar', 'Kopnx Vaewq', 'Uxzxkkse Jarkyzwf', 'Yqakst Bbtvfdgv', 'Kubedcgw Izdsilee', 'Fufdj Ffeggwj', 'Jfvdku Swzegj', 'Updfas Oxorjlll', 'Gfnybxtl Wdtaqdq', 'Dtmbkwd Gcojxx', 'Qxyhh Zpcpq', 'Zkljb Dmtdxc', 'Kviumtu Kscevwfn', 'Yfgsen Mxngnngm', 'Plhzfg Elksvka', 'Thqpcswd Ustify', 'Dglimzd Kunwmoaq', 'Wkluu Okhode', 'Gklvlo Nuwoocoj', 'Hiulcvz Sevdabtx', 'Kqikvo Yiozzlfm', 'Eyqfqtq Htacvlz', 'Zpkymd Chkpor', 'Zzrbzwu Cfkamhle', 'Ojeyrc Ebuxhwi', 'Cswujyff Qpgjar', 'Kjucz Gipbkz', 'Grcvjczk Udntv', 'Shscraug Qgiruzro', 'Mfngw Isowo', 'Xptod Xsgkvhec', 'Wfkua Vsuizy', 'Lpnhfoo Bqafu', 'Wqoiymnf Pcwpgln', 'Mjyeil Srcozsnz', 'Nlxfdq Auekqaz', 'Gtzuboho Lnsdrh', 'Idzeih Ltphoxbj', 'Jkhbx Bvrldcdf', 'Adrso Rybohuki', 'Ptebiymn Hkxkj', 'Jqdswgu Ycduwhh', 'Fvhykhd Ktjvznwx', 'Dzfca Nlfwu', 'Vxvxx Plothiif', 'Ezdvpq Ubelj', 'Bdrizsx Vgusb', 'Tpthie Inpev', 'Hzappwb Dmigofrn', 'Jzaisxq Rgtfsrgj', 'Mvmlsdzr Fsgbg', 'Cfluchs Nwusnnl', 'Ykcgal Gmzyveir', 'Zphhtp Smniw', 'Yoyvy Joxbvkh', 'Ecynhl Lefkrhhj', 'Jdebrwc Wcwpbxc', 'Fgfdaei Tvbqy', 'Ipfkuwur Xpxtji', 'Rtgqgwmv Lokardbu', 'Ikxxtkor Nunsrvbr', 'Pzvrho Yjwjk', 'Lbdnj Jnupzo', 'Iuhiqsil Rcnyid', 'Wwucpsf Kenpo', 'Qkzalavo Axyonydy', 'Xiryvz Fnbtxsjl', 'Edymarrv Aznhlz', 'Bnupsf Mspvaibq', 'Eqgyrnbt Jiydb', 'Gtoixcoc Ptpoot', 'Vtxfgldg Edlpn', 'Bhywbmgq Mujjyb', 'Etpyra Eitfwk', 'Oeaarco Cvxea', 'Yrbfxpe Axluion', 'Xxuck Iuxvx', 'Ledoylr Qiwadtoo', 'Tddqb Zqsedf', 'Szvhp Rwdozgb', 'Nzpwqiep Uqctco', 'Tzirfnik Iihlqn', 'Keddp Wnohin', 'Rnqsxaci Fyuur', 'Fpjvs Yodjg', 'Purzi Rzicwq', 'Frmwxdel Kvzhm', 'Ostitnh Sbnnak', 'Exbmsyh Mlxcc', 'Lsdasdjf Gzzsyo', 'Tbuurxc Dbwez', 'Cyouunx Iibnybq', 'Xrtakk Dinzr', 'Eiyidsl Egkntj', 'Daqqs Asdqzgnr', 'Lhzwcoii Nvuiehei', 'Gdamyax Idktkzg', 'Lhjld Bbihzv', 'Mxysb Jbitoj', 'Vfwojin Kqedhapo', 'Kfbysgnj Zboofd', 'Rntyyue Otxzwb', 'Hpskgia Illufse', 'Zcuind Ieyklc', 'Lwcrh Bwxlwbho', 'Jihsrp Bhsmf', 'Uwkrap Xovyozge', 'Gucegc Lakfd', 'Obdbhh Rotfhasw', 'Yywddfgp Gehrut', 'Bpryhr Ouinxb', 'Esoncj Tombli', 'Rrohx Fyyayk', 'Okjeuoru Hvdprx', 'Rlwqyp Npszpli', 'Bdsrrr Jqyda', 'Lbybmh Estmfea', 'Wiiolrsm Qbwokykd', 'Topiv Vaodkl', 'Uwvarcu Aknmkwq', 'Lohzd Fhmbf', 'Tvtwf Epyyde', 'Wedjim Zxdoju', 'Iqmpm Aakuzylo', 'Ghsuo Ilggpd', 'Qafcf Zgaozil', 'Vqrnztc Cfrjlcqu', 'Jnwuh Wyialc', 'Kjljuh Hynsxj', 'Hwsph Kiyzzqxz', 'Kktuofq Tjchlogp', 'Yyzcqp Jbtftp', 'Itvdv Xxcwmtvh', 'Qverbur Hsznh', 'Qjxyhw Uzkeix', 'Fjmld Dzmak', 'Aamsmtmw Ehtao', 'Lnhtxiy Gagrea', 'Nbxdpwbn Rfnrdx', 'Ujiejk Ernrjdx', 'Tdwgwac Axcnm', 'Aojqyehm Axmwn', 'Bcglktdv Bmvpw', 'Zgvpwjio Xciivzv', 'Igmqiv Zkaxy', 'Zykmhh Yuqqjxut', 'Mwsudx Dqcxxice', 'Nrmuryho Cfgdqw', 'Aqvvgu Qnczw', 'Lkiohg Xdxhdnd', 'Zwcnxll Kwhoi', 'Dnstw Rkcrxf', 'Giexlx Fiupskm', 'Rkzihtt Vxtrjlfj', 'Uwhbufs Agjjnayx', 'Nlkda Nxepy', 'Nenchfo Tepar', 'Eanpsyge Pxhdhd', 'Yespi Bjfdw', 'Jjkqo Fnwsh', 'Tmgtso Zgfduuf', 'Amllysun Inzfyonv', 'Bfbyp Afjfvav', 'Tsjbpzju Vjuun', 'Wylewz Qzltxpyh', 'Doost Rxgnl', 'Yuiuqx Ydhau', 'Bahhsro Gywpchx', 'Czblrrmu Rbhxhni', 'Iigpjl Ntffc', 'Qwwfx Ayldavn', 'Yngpv Rtjhn', 'Lwqfg Jdimlhf', 'Mronh Fmizdheq', 'Mscbos Dflapcu', 'Pczdrzcz Iulua', 'Uappy Tlvnfh', 'Ddkwwxw Xfxubnfx', 'Wdvunb Vzdsxp', 'Vvhilqyg Vorzktxn', 'Ejlxgv Ezbvbr', 'Hocgpi Yowggl', 'Ycvofx Gltohuq', 'Zvpku Uwbxel', 'Hdwvxbsp Erjqdr', 'Qbxutien Ppbpy', 'Byumjjpj Snmjeaj', 'Ngkkl Yhwmjnf', 'Hiewulhn Ziqklvx', 'Xndazwv Zzqrfo', 'Fztkpruq Sfxun', 'Zwfhmom Ywppssr', 'Qmqqi Wufbg', 'Yusub Nsozrckd', 'Awlphew Fxapske', 'Kedpew Alwintkj', 'Lawbggac Punyhau', 'Ocjdqdaj Vlsqpr', 'Ojzhej Ccvqzql', 'Pfxnp Saghm', 'Bjgzrh Byhriq', 'Zevyzaed Ewaej', 'Lwlh ...
# De capricornio, en verano nacieron 2140
# ('Acjllyme Wlipcqgl', 2002, 12, 30, 'ARG')
# ('Ehwzaa Iownhj', 1940, 1, 8, 'ARG')
# ('999156', 120, '9241.15033333243')
# ['91893', '44313', '28488', '11260', '15873', '30337', '55951', '31980', '68008', '2922', '33092', '3899', '17248', '22141', '71612', '16426', '34846', '18480', '99301', '16045', '22736', '79738', '43020', '40784', '80976', '82507', '69223', '76117', '78945', '36956', '53856', '67929', '88429', '45210', '70319', '9825', '91932', '69004', '36080', '10383', '71119', '97830', '28386', '79582', '68006', '97642', '66116', '12919', '60987', '17924', '31903', '48886', '59538', '96553', '98871', '25495', '59833', '91221', '95146', '78183', '63603', '63488', '2688', '50467', '56917', '11023', '9993', '54813', '77998', '21003', '81561', '25219', '76944', '15872', '6458', '46238', '48464', '74612', '53000', '56247', '52921', '53423', '42745', '7057', '68980', '10442', '92530', '53397', '46247', '18127', '40456', '97611', '2733', '39558', '11344', '76004', '69550', '72857', '50596', '33162', '35379', '30952', '88885', '67319', '41138', '49840', '79696', '82112', '82614', '83797', '82212', '58116', '41754', '14298', '39861', '4283', '82116', '55064', '66849', '67636', '81574', '54533', '39794', '18381', '79991', '70359', '15097', '87994', '19326', '69216', '28724', '89589', '80757', '98646', '27934', '15943', '33329', '29804', '53203', '18387', '91619', '95925', '54746', '69253', '51177', '56054', '76146', '49282', '6413', '52066', '63900', '46404', '60049', '422', '40854', '28663', '80960', '29861', '66116', '2015', '92392', '53055', '27801', '71936', '5353', '33467', '26576', '35189', '99103', '97806', '9494', '76148', '40618', '81059', '19517', '84417', '69148', '99314', '47555', '89634', '29535', '35774', '42772', '68724', '19307', '32367', '1581', '28631', '50288', '16614', '29367', '28793', '61222', '48717', '93830', '11440', '46407', '7985', '27846', '51706', '48176', '45856', '49009', '51714', '34439', '643', '79566', '42393', '14235', '53611', '17857', '71680', '1748', '14081', '46188', '36250', '39223', '35024', '19560', '91269', '83865', '87286', '25439', '52759', '7454', '52627', '27029', '1875', '59877', '37696', '75463', '9946', '5132', '28247', '26406', '78926', '80845', '88826', '59571', '30340', '61555', '33948', '61219', '32822', '10017', '70869', '39143', '48553', '78131', '40838', '67679', '43463', '32790', '22778', '25015', '73331', '41493', '48521', '21568', '53468', '1233', '76311', '1918', '94154', '16586', '17152', '53987', '48845', '53116', '43492', '59297', '38081', '34296', '15254', '74345', '2156', '86555', '4351', '1883', '77891', '55489', '27488', '80428', '24568', '93091', '17022', '41361', '42324', '19089', '61444', '28054', '30280', '287', '63467', '67586', '5824', '21060', '78101', '12128', '33779', '76973', '42249', '39536', '52391', '15937', '79675', '74660', '4350', '46715', '73374', '68756', '6373', '63112', '51582', '52444', '34744', '34027', '27280', '81275', '50313', '31695', '11973', '40146', '86832', '27264', '87623', '63767', '83956', '54452', '99579', '95084', '68416', '15770', '52745', '62934', '68392', '79122', '53139', '31092', '65077', '24363', '80597', '67135', '95062', '73471', '21366', '92256', '50029', '60467', '57976', '21611', '56859', '84229', '21034', '85912', '78960', '5215', '88738', '77343', '70112', '96195', '34394', '82879', '81518', '66877', '97508', '20213', '80897', '71630', '36770', '89276', '1582', '80076', '53925', '79561', '20783', '80845', '15310', '56175', '18252', '44709', '69755', '4839', '35090', '811', '60257', '42037', '16338', '64701', '67776', '26673', '71675', '67152', '56457', '95522', '12802', '20072', '74851', '96919', '47755', '73912', '42104', '26951', '45163', '97899', '57470', '18818', '52363', '10571', '10820', '99699', '72168', '35365', '28360', '41917', '46123', '88987', '1216', '7401', '12131', '21890', '77489', '18124', '49349', '57040', '63972', '22798', '57976', '72020', '65964', '78', '84532', '58614', '33410', '15472', '35146', '20090', '28083', '39360', '92685', '8681', '19514', '21235', '98937', '60194', '19374', '65370', '79237', '75141', '53 ...
# Monto del mayor movimiento: 49999.6163882313
# ID de caja del ultimo mov: 134039

# %% [markdown]
# **Ejercicio 5 - Estaciones**
#
# P: desde Spark, con textFile no es posible seleccionar un conjunto de archivos por prefijo, siempre agarra la carpeta entera. No queda otra que separ los archivos de distinto tipo en subcarpetas.

# %%
## EJERCICIO 5 - ESTACIONES

root_path = 'drive/My Drive/Colab Notebooks/'

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

import datetime, math
import sys
sys.path.append('/content/' + root_path)

inputDir = root_path + "EstacionesMeteorologicas/"

# ------------------- transformaciones ----------------------

# <ID_Estación, fecha_registro, temperatura, humedad, precipitación>
# norte: en grados centigrados y mm
# sur: en grados fahrenheit tc = (tf - 32) * 1.8, y cm

def splitter(linea):
  return linea.split('\t')

def celsius(fahrenheit):
  return 1.8 * (int(fahrenheit) - 32)

def cm(mm):
  return 10 * int(mm)

# ------------------- carga de archivos ----------------------

norte = sc.textFile(inputDir + "Norte").map(splitter)
sur = sc.textFile(inputDir + "Sur").map(splitter)

# conversion a enteros y a sistema internacional
norte = norte.map(lambda e: (e[0], e[1], int(e[2]), int(e[3]), int(e[4])) )
sur = sur.map(lambda e: (e[0], e[1], celsius(e[2]), int(e[3]), cm(e[4]) ) )

# juntar datasets
estaciones = norte.union(sur)

## Parte 1: promedio de temperatura, humedad y precipitacion
part1 = estaciones.map(lambda e: (e[2], e[3], e[4], 1) )
sumas = part1.reduce(lambda e1, e2: (e1[0] + e2[0], e1[1] + e2[1], e1[2] + e2[2], e1[3] + e2[3]) )
promedios = (sumas[0] / sumas[3], sumas[1] / sumas[3], sumas[2] / sumas[3])
print(promedios)

## Parte 2:
# minimos y maximos: de esta forma es 4 veces más rápido
part2 = estaciones.map(lambda e: (e[2], e[2], e[3], e[3], e[4], e[4]) )
part2 = part2.reduce(lambda e1, e2: 
                          (e1[0] if e1[0] < e2[0] else e2[0], 
                           e1[1] if e1[1] > e2[1] else e2[1],
                           e1[2] if e1[2] > e2[2] else e2[2],
                           e1[3] if e1[3] < e2[3] else e2[3],
                           e1[4] if e1[4] > e2[4] else e2[4],
                           e1[5] if e1[5] < e2[5] else e2[5]) 
                          )

print(part2)

# la temperatura mas fria
#coldest = estaciones.reduce(lambda e1, e2: e1 if e1[2] < e2[2] else e2)

# la mas calurosa
#hotter = estaciones.reduce(lambda e1, e2: e1 if e1[2] > e2[2] else e2)

# mayor humedad
#mayorHum = estaciones.reduce(lambda e1, e2: e1 if e1[3] > e2[3] else e2)

# menor humedad
#menorHum = estaciones.reduce(lambda e1, e2: e1 if e1[3] < e2[3] else e2)

# mayor precipitacion
#mayorPrec = estaciones.reduce(lambda e1, e2: e1 if e1[4] > e2[4] else e2)

# menor precipitación
#menorPrec = estaciones.reduce(lambda e1, e2: e1 if e1[4] < e2[4] else e2)

# salida
#print(coldest)
#print(hotter)
#print(mayorHum)
#print(menorHum)
#print(mayorPrec)
#print(menorPrec)
# Out:
# Mounted at /content/drive
# (8.37301267501466, 49.94118997220168, 5038.977990869909)
# (-84.60000000000001, 100, 100, 0, 20010, 0)
